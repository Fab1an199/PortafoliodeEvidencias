# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import matplotlib.pyplot as plt
from ydata_profiling import ProfileReport
#----------------------------------------#
from scipy.stats import zscore
import seaborn as sns
import warnings
warnings.filterwarnings("ignore", category=FutureWarning, module='seaborn')
#----------------------------------------#
from sklearn import linear_model
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
#----------------------------------------#
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("00-DataSet/DataSet.csv", sep=";", low_memory=False)
print("Datos Cargados")
# Out:
# Datos Cargados

# %%
df.head(5)
# Out:
#     mpg  Cylinders desplAcemenT  horsepower Weight acceleration  model year  \
# 0  18.0          8          307       130.0   3504           12          70
# 1  15.0          8          350       165.0   3693         11,5          70
# 2  18.0          8          318       150.0   3436           11          70
# 3  16.0          8          304       150.0   3433           12          70
# 4  17.0          8          302       140.0   3449         10,5          70
#
#    Origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
profile = ProfileReport(df, title = "ELT_MPG")
profile. to_notebook_iframe()
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling vv4.10.0&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2024-11-18 03:56:21.412434&quot;&gt;&lt;title&gt;ELT_MPG&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %% [markdown]
# Eliminar Duplicados

# %%
df.shape
# Out:
# (416, 9)

# %%
df.drop_duplicates(subset=None, keep='first', inplace=True, ignore_index=True)
df.shape
# Out:
# (409, 9)

# %% [markdown]
# Manejo de Faltantes

# %%
dfNull=df[df.mpg.isnull()]
dfNull.shape
# Out:
# (8, 9)

# %%
dfNull.head(8)
# Out:
#      mpg  Cylinders desplAcemenT  horsepower Weight acceleration  model year  \
# 10   NaN          4          133       115.0   3090         17,5          70
# 11   NaN          8          350       165.0   4142         11,5          70
# 12   NaN          8          351       153.0   4034           11          70
# 13   NaN          8          383       175.0   4166         10,5          70
# 14   NaN          8          360       175.0   3850           11          70
# 17   NaN          8          302       140.0   3353            8          70
# 39   NaN          4           97        48.0   1978           20          71
# 367  NaN          4          121       110.0   2800         15,4          81
#
#      Origin                          car name
# 10        2              citroen ds-21 pallas
# 11        1  chevrolet chevelle concours (sw)
# 12        1                  ford torino (sw)
# 13        1           plymouth satellite (sw)
# ...

# %%
df_Null = df[df['car name'] == 'citroen ds-21 pallas']
df_Null.head(10)
# Out:
#     mpg  Cylinders desplAcemenT  horsepower Weight acceleration  model year  \
# 10  NaN          4          133       115.0   3090         17,5          70
#
#     Origin              car name
# 10       2  citroen ds-21 pallas

# %%
df_Null = df[df['car name'] == 'chevrolet chevelle concours (sw)']
df_Null.head(10)
# Out:
#      mpg  Cylinders desplAcemenT  horsepower Weight acceleration  model year  \
# 11   NaN          8          350       165.0   4142         11,5          70
# 80  13.0          8          307       130.0   4098           14          72
#
#     Origin                          car name
# 11       1  chevrolet chevelle concours (sw)
# 80       1  chevrolet chevelle concours (sw)

# %%
df_Null = df[df['car name'] == 'ford torino (sw)']
df_Null.head(10)
# Out:
#     mpg  Cylinders desplAcemenT  horsepower Weight acceleration  model year  \
# 12  NaN          8          351       153.0   4034           11          70
#
#     Origin          car name
# 12       1  ford torino (sw)

# %%
df_Null = df[df['car name'] == 'plymouth satellite (sw)']
df_Null.head(10)
# Out:
#     mpg  Cylinders desplAcemenT  horsepower Weight acceleration  model year  \
# 13  NaN          8          383       175.0   4166         10,5          70
#
#     Origin                 car name
# 13       1  plymouth satellite (sw)

# %%
df_Null = df[df['car name'] == 'amc rebel sst (sw)']
df_Null.head(10)
# Out:
#     mpg  Cylinders desplAcemenT  horsepower Weight acceleration  model year  \
# 14  NaN          8          360       175.0   3850           11          70
#
#     Origin            car name
# 14       1  amc rebel sst (sw)

# %%
df_Null = df[df['car name'] == 'ford mustang boss 302']
df_Null.head(10)
# Out:
#     mpg  Cylinders desplAcemenT  horsepower Weight acceleration  model year  \
# 17  NaN          8          302       140.0   3353            8          70
#
#     Origin               car name
# 17       1  ford mustang boss 302

# %%
df_Null = df[df['car name'] == 'volkswagen super beetle 117']
df_Null.head(10)
# Out:
#     mpg  Cylinders desplAcemenT  horsepower Weight acceleration  model year  \
# 39  NaN          4           97        48.0   1978           20          71
#
#     Origin                     car name
# 39       2  volkswagen super beetle 117

# %%
df_Null = df[df['car name'] == 'saab 900s']
df_Null.head(10)
# Out:
#      mpg  Cylinders desplAcemenT  horsepower Weight acceleration  model year  \
# 367  NaN          4          121       110.0   2800         15,4          81
#
#      Origin   car name
# 367       2  saab 900s

# %%
avMPG = df['mpg'].astype('float').mean(axis=0)  
avMPG = float(avMPG)
avMPG
# Out:
# 23.60798004987531

# %%
df['mpg'].replace(np.nan, 23.6, inplace=True)
print('Valores Faltantes Imputados')
# Out:
# Valores Faltantes Imputados
# C:\Users\USER\AppData\Local\Temp\ipykernel_33392\3454441059.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['mpg'].replace(np.nan, 23.6, inplace=True)

# %%
dfNull=df[df.horsepower.isnull()]
dfNull.shape
# Out:
# (6, 9)

# %%
dfNull.head(6)
# Out:
#       mpg  Cylinders desplAcemenT  horsepower Weight acceleration  model year  \
# 38   25.0          4           98         NaN   2046           19          71
# 133  21.0          6          200         NaN   2875           17          74
# 337  40.9          4           85         NaN   1835         17,3          80
# 343  23.6          4          140         NaN   2905         14,3          80
# 361  34.5          4          100         NaN   2320         15,8          81
# 382  23.0          4          151         NaN   3035         20,5          82
#
#      Origin              car name
# 38        1            ford pinto
# 133       1         ford maverick
# 337       2  renault lecar deluxe
# 343       1    ford mustang cobra
# 361       2           renault 18i
# 382       1        amc concord dl

# %%
dfNull2=df[df['car name'] == 'ford maverick']
dfNull2.head(7)
# Out:
#       mpg  Cylinders desplAcemenT  horsepower Weight acceleration  model year  \
# 23   21.0          6          200        85.0   2587           16          70
# 107  18.0          6          250        88.0   3021         16,5          73
# 133  21.0          6          200         NaN   2875           17          74
# 162  15.0          6          250        72.0   3158         19,5          75
# 200  24.0          6          200        81.0   3012         17,6          76
#
#      Origin       car name
# 23        1  ford maverick
# 107       1  ford maverick
# 133       1  ford maverick
# 162       1  ford maverick
# 200       1  ford maverick

# %%
average = dfNull2['horsepower'].astype('float').mean(axis=0)
average = float(average)
average
# Out:
# 81.5

# %%
df.loc[133,'horsepower'] = 81.5

# %%
dfNull2=df[df['car name'] == 'ford maverick']
dfNull2.head(7)
# Out:
#       mpg  Cylinders desplAcemenT  horsepower Weight acceleration  model year  \
# 23   21.0          6          200        85.0   2587           16          70
# 107  18.0          6          250        88.0   3021         16,5          73
# 133  21.0          6          200        81.5   2875           17          74
# 162  15.0          6          250        72.0   3158         19,5          75
# 200  24.0          6          200        81.0   3012         17,6          76
#
#      Origin       car name
# 23        1  ford maverick
# 107       1  ford maverick
# 133       1  ford maverick
# 162       1  ford maverick
# 200       1  ford maverick

# %%
average = df['horsepower'].astype('float').mean(axis=0)
average = float(average)
average
# Out:
# 104.74133663366337

# %%
df['horsepower'].replace(np.nan, 104.7, inplace=True)
print('Valores Faltantes Imputados')
# Out:
# Valores Faltantes Imputados
# C:\Users\USER\AppData\Local\Temp\ipykernel_33392\4078718262.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['horsepower'].replace(np.nan, 104.7, inplace=True)

# %% [markdown]
# Formateo de los Datos

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 409 entries, 0 to 408
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           409 non-null    float64
#  1   Cylinders     409 non-null    int64
#  2   desplAcemenT  409 non-null    object
#  3   horsepower    409 non-null    float64
#  4   Weight        409 non-null    object
#  5   acceleration  409 non-null    object
#  6   model year    409 non-null    int64
#  7   Origin        409 non-null    int64
#  8   car name      409 non-null    object
# dtypes: float64(2), int64(3), object(4)
# memory usage: 28.9+ KB

# %%
df.head(5)
# Out:
#     mpg  Cylinders desplAcemenT  horsepower Weight acceleration  model year  \
# 0  18.0          8          307       130.0   3504           12          70
# 1  15.0          8          350       165.0   3693         11,5          70
# 2  18.0          8          318       150.0   3436           11          70
# 3  16.0          8          304       150.0   3433           12          70
# 4  17.0          8          302       140.0   3449         10,5          70
#
#    Origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %% [markdown]
# Hay que trabajar Weight, desplAcemenT y acceleration

# %%
df[df.desplAcemenT.str.contains(",", case=False)]
# Out:
#      mpg  Cylinders desplAcemenT  horsepower Weight acceleration  model year  \
# 65  25.0          4         97,5        80.0   2126           17          72
#
#     Origin            car name
# 65       1  dodge colt hardtop

# %%
df['desplAcemenT'] = df['desplAcemenT'].str.replace(",", ".")  
df[['desplAcemenT']] = df[['desplAcemenT']].astype("float")  
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 409 entries, 0 to 408
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           409 non-null    float64
#  1   Cylinders     409 non-null    int64
#  2   desplAcemenT  409 non-null    float64
#  3   horsepower    409 non-null    float64
#  4   Weight        409 non-null    object
#  5   acceleration  409 non-null    object
#  6   model year    409 non-null    int64
#  7   Origin        409 non-null    int64
#  8   car name      409 non-null    object
# dtypes: float64(3), int64(3), object(3)
# memory usage: 28.9+ KB

# %%
df[df.Weight.str.contains("w", case=False)]
# Out:
#       mpg  Cylinders  desplAcemenT  horsepower Weight acceleration  \
# 406  38.0          4          91.0        67.0  W1965           15
# 407  32.0          4          91.0        67.0  W1965         15,7
# 408  38.0          4          91.0        67.0  W1965         16,2
#
#      model year  Origin            car name
# 406          82       3         honda civic
# 407          82       3  honda civic (auto)
# 408          82       3       datsun 310 gx

# %%
df.loc[406,"Weight"] = 1965
df.loc[407,"Weight"] = 1965
df.loc[408,"Weight"] = 1965
df[['Weight']] = df[['Weight']].astype("float")  
df.dtypes
# Out:
# mpg             float64
# Cylinders         int64
# desplAcemenT    float64
# horsepower      float64
# Weight          float64
# acceleration     object
# model year        int64
# Origin            int64
# car name         object
# dtype: object

# %%
df['acceleration'] = df['acceleration'].str.replace(",", ".")  
df[['acceleration']] = df[['acceleration']].astype("float")  
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 409 entries, 0 to 408
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           409 non-null    float64
#  1   Cylinders     409 non-null    int64
#  2   desplAcemenT  409 non-null    float64
#  3   horsepower    409 non-null    float64
#  4   Weight        409 non-null    float64
#  5   acceleration  409 non-null    float64
#  6   model year    409 non-null    int64
#  7   Origin        409 non-null    int64
#  8   car name      409 non-null    object
# dtypes: float64(5), int64(3), object(1)
# memory usage: 28.9+ KB

# %%
df.columns = [col.upper() for col in df.columns]
df.columns
# Out:
# Index(['MPG', 'CYLINDERS', 'DESPLACEMENT', 'HORSEPOWER', 'WEIGHT',
#        'ACCELERATION', 'MODEL YEAR', 'ORIGIN', 'CAR NAME'],
#       dtype='object')

# %%
df.to_excel("01-Salidas/DSFormato.xlsx")
