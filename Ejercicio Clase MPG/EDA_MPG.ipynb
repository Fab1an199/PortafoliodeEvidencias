# %%
import pandas as pd       #Se usa para el manejo de los DataFrame
import numpy as np        #Se usa para el manejo de las estructuras de datos (Array, Listas, Tuplas, Diccionarios)
import matplotlib.pyplot as plt #Se usa para crear las graficas.
import plotly.express as px
import matplotlib as mpl
import seaborn as sns
#------------------------------------#
from scipy.stats import zscore
import seaborn as sns
import warnings
warnings.filterwarnings("ignore", category=FutureWarning, module='seaborn')
#-------------------------------------#
from sklearn import linear_model
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
df = pd.read_excel("01-Salidas/DSFormato.xlsx")

# %%
df.drop(['Unnamed: 0'], axis=1, inplace=True)
df.head(5)
# Out:
#     MPG  CYLINDERS  DESPLACEMENT  HORSEPOWER  WEIGHT  ACCELERATION  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    MODEL YEAR  ORIGIN                   CAR NAME
# 0          70       1  chevrolet chevelle malibu
# 1          70       1          buick skylark 320
# 2          70       1         plymouth satellite
# 3          70       1              amc rebel sst
# 4          70       1                ford torino

# %%
#Filtrar las columnas numericas
df_numerico = df.select_dtypes(include='number')
 
#Configurar tamano de los graficos
num_vars = len(df_numerico.columns)
cols = 4
rows = (num_vars // cols) + (num_vars % cols > 0)
 
plt.figure(figsize=(20, rows * 4))
 
#Usar una paleta de colores
paleta = sns.color_palette("Set2", num_vars)
 
#Crear un histograma por cada variable
for i, columna in enumerate(df_numerico.columns, 1):
    plt.subplot(rows, cols, i)
    sns.histplot(df_numerico[columna].dropna(), kde=True, color=paleta[i-1], bins=20)
    plt.title(f'Histograma de {columna}', fontsize=14)
    plt.xlabel('Valores', fontsize=12)
    plt.ylabel('Frecuencia', fontsize=12)
 
#Ajusto espacio y muestro grafico
plt.tight_layout()
plt.show()

# %%
#Filtrar las columnas numericas
df_numerico = df.select_dtypes(include='number')
 
#Configurar tamano de los graficos
num_vars = len(df_numerico.columns)
cols = 4
rows = (num_vars // cols) + (num_vars % cols > 0)
 
plt.figure(figsize=(20, rows * 4))
 
#Usar una paleta de colores
paleta = sns.color_palette("Set2", num_vars)
 
#Crear un histograma por cada variable
for i, columna in enumerate(df_numerico.columns, 1):
    plt.subplot(rows, cols, i)
    sns.boxplot(y=df_numerico[columna], color=paleta[i-1], fliersize=5)
    plt.title(f'Boxplot de {columna}', fontsize=14)
    plt.ylabel('Valores', fontsize=12)
    plt.xticks([])
 
#Ajusto espacio y muestro grafico
plt.tight_layout()
plt.show()

# %%
df.head(5)
# Out:
#     MPG  CYLINDERS  DESPLACEMENT  HORSEPOWER  WEIGHT  ACCELERATION  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    MODEL YEAR  ORIGIN                   CAR NAME
# 0          70       1  chevrolet chevelle malibu
# 1          70       1          buick skylark 320
# 2          70       1         plymouth satellite
# 3          70       1              amc rebel sst
# 4          70       1                ford torino

# %%
def OutlierIQR(df, column):
    # Calcular Q25 y Q75
    seventy_fifth = df[column].quantile(0.75)
    twenty_fifth = df[column].quantile(0.25)
 
    # Calcular el IQR
    iqr = seventy_fifth - twenty_fifth
 
    # Calcular los límites (superior e inferior)
    upper = seventy_fifth + (1.5 * iqr)
    lower = twenty_fifth - (1.5 * iqr)
 
    # Filtrar los outliers
    filtered_df = df[(df[column] >= lower) & (df[column] <= upper)]
 
    return filtered_df
 
df = OutlierIQR(df, 'MPG')
df = OutlierIQR(df, 'HORSEPOWER')
df = OutlierIQR(df, 'ACCELERATION')

# %%
# Filtrar las columnas numéricas  
df_numerico = df.select_dtypes(include='number')  

# Configurar tamaño de los gráficos  
num_vars = len(df_numerico.columns)  
cols = 4  
rows = (num_vars // cols) + (num_vars % cols > 0)  

plt.figure(figsize=(20, rows * 4))

# %%
#Filtrar las columnas numericas
df_numerico = df.select_dtypes(include='number')
 
#Configurar tamano de los graficos
num_vars = len(df_numerico.columns)
cols = 4
rows = (num_vars // cols) + (num_vars % cols > 0)
 
plt.figure(figsize=(20, rows * 4))
 
#Usar una paleta de colores
paleta = sns.color_palette("Set2", num_vars)
 
#Crear un histograma por cada variable
for i, columna in enumerate(df_numerico.columns, 1):
    plt.subplot(rows, cols, i)
    sns.boxplot(y=df_numerico[columna], color=paleta[i-1], fliersize=5)
    plt.title(f'Boxplot de {columna}', fontsize=14)
    plt.ylabel('Valores', fontsize=12)
    plt.xticks([])
 
#Ajusto espacio y muestro grafico
plt.tight_layout()
plt.show()

# %%
df.shape
# Out:
# (389, 9)

# %%
#Filtrar las columnas numericas
df_numerico = df.select_dtypes(include='number')
 
#Configurar tamano de los graficos
num_vars = len(df_numerico.columns)
cols = 4
rows = (num_vars // cols) + (num_vars % cols > 0)
 
plt.figure(figsize=(20, rows * 4))
 
#Usar una paleta de colores
paleta = sns.color_palette("Set2", num_vars)
 
#Crear un histograma por cada variable
for i, columna in enumerate(df_numerico.columns, 1):
    plt.subplot(rows, cols, i)
    sns.histplot(df_numerico[columna].dropna(), kde=True, color=paleta[i-1], bins=20)
    plt.title(f'Histograma de {columna}', fontsize=14)
    plt.xlabel('Valores', fontsize=12)
    plt.ylabel('Frecuencia', fontsize=12)
 
#Ajusto espacio y muestro grafico
plt.tight_layout()
plt.show()

# %%
#Reduccion de Caracteristicas

# %%
df.dtypes
# Out:
# MPG             float64
# CYLINDERS         int64
# DESPLACEMENT    float64
# HORSEPOWER      float64
# WEIGHT            int64
# ACCELERATION    float64
# MODEL YEAR        int64
# ORIGIN            int64
# CAR NAME         object
# dtype: object

# %%
df.columns
# Out:
# Index(['MPG', 'CYLINDERS', 'DESPLACEMENT', 'HORSEPOWER', 'WEIGHT',
#        'ACCELERATION', 'MODEL YEAR', 'ORIGIN', 'CAR NAME'],
#       dtype='object')

# %%
dfMat = df.loc[:, ['MPG', 'CYLINDERS', 'DESPLACEMENT', 'HORSEPOWER', 'WEIGHT', 'ACCELERATION', 'MODEL YEAR', 'ORIGIN']]  
dfMat.columns
# Out:
# Index(['MPG', 'CYLINDERS', 'DESPLACEMENT', 'HORSEPOWER', 'WEIGHT',
#        'ACCELERATION', 'MODEL YEAR', 'ORIGIN'],
#       dtype='object')

# %%
correlacion = dfMat.corr(method = 'pearson')  
correlacion.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_a5db8_row0_col0, #T_a5db8_row1_col1, #T_a5db8_row2_col2, #T_a5db8_row3_col3, #T_a5db8_row4_col4, #T_a5db8_row5_col5, #T_a5db8_row6_col6, #T_a5db8_row7_col7 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_a5db8_row0_col1, #T_a5db8_row0_col2, #T_a5db8_row0_col3, #T_a5db8_row0_col4, #T_a5db8_row2_col7, #T_a5db8_row3_col5, #T_a5db8_row3_col6, #T_a5db8_row4_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_a5db8_row0_col5 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_a5db8_row0_col6 {
#   background-color: #f7b79b;
#   color: #000000;
# }
# #T_a5db8_row0_col7 {
#   background-color: #f5a081;
#   color: #000000;
# }
# #T_a5db8_row1_col0, #T_a5db8_row1_col7 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_a5db8_row1_col2, #T_a5db8_row2_col1 {
#   background-color: #bd1f2d;
#   color: #f1f1f1;
# }
# #T_a5db8_row1_col3, #T_a5db8_row3_col1 {
#   background-color: #d1493f;
#   color: #f1f1f1;
# }
# #T_a5db8_row1_col4 {
#   background-color: #c83836;
#   color: #f1f1f1;
# }
# #T_a5db8_row1_col5, #T_a5db8_row3_col7, #T_a5db8_row7_col2 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_a5db8_row1_col6 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_a5db8_row2_col0 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_a5db8_row2_col3, #T_a5db8_row3_col2, #T_a5db8_row3_col4 {
#   background-color: #cb3e38;
#   color: #f1f1f1;
# }
# #T_a5db8_row2_col4, #T_a5db8_row4_col2 {
#   background-color: #c0282f;
#   color: #f1f1f1;
# }
# #T_a5db8_row2_col5 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_a5db8_row2_col6, #T_a5db8_row4_col7 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_a5db8_row3_col0 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_a5db8_row4_col1 {
#   background-color: #ca3b37;
#   color: #f1f1f1;
# }
# #T_a5db8_row4_col3 {
#   background-color: #cc403a;
#   color: #f1f1f1;
# }
# #T_a5db8_row4_col5, #T_a5db8_row5_col2 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_a5db8_row4_col6, #T_a5db8_row5_col3 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_a5db8_row5_col0 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_a5db8_row5_col1 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_a5db8_row5_col4 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_a5db8_row5_col6 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_a5db8_row5_col7 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_a5db8_row6_col0 {
#   background-color: #f4987a;
#   color: #000000;
# }
# #T_a5db8_row6_col1 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_a5db8_row6_col2 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_a5db8_row6_col3 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_a5db8_row6_col4 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_a5db8_row6_col5 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_a5db8_row6_col7 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_a5db8_row7_col0 {
#   background-color: #f39577;
#   color: #000000;
# }
# #T_a5db8_row7_col1 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_a5db8_row7_col3 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_a5db8_row7_col4 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_a5db8_row7_col5 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_a5db8_row7_col6 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# </style>
# <table id="T_a5db8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a5db8_level0_col0" class="col_heading level0 col0" >MPG</th>
#       <th id="T_a5db8_level0_col1" class="col_heading level0 col1" >CYLINDERS</th>
#       <th id="T_a5db8_level0_col2" class="col_heading level0 col2" >DESPLACEMENT</th>
#       <th id="T_a5db8_level0_col3" class="col_heading level0 col3" >HORSEPOWER</th>
#       <th id="T_a5db8_level0_col4" class="col_heading level0 col4" >WEIGHT</th>
#       <th id="T_a5db8_level0_col5" class="col_heading level0 col5" >ACCELERATION</th>
#       <th id="T_a5db8_level0_col6" class="col_heading level0 col6" >MODEL YEAR</th>
#       <th id="T_a5db8_level0_col7" class="col_heading level0 col7" >ORIGIN</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a5db8_level0_row0" class="row_heading level0 row0" >MPG</th>
#       <td id="T_a5db8_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_a5db8_row0_col1" class="data row0 col1" >-0.762152</td>
#       <td id="T_a5db8_row0_col2" class="data row0 col2" >-0.794552</td>
#       <td id="T_a5db8_row0_col3" class="data row0 col3" >-0.767314</td>
#       <td id="T_a5db8_row0_col4" class="data row0 col4" >-0.828215</td>
#       <td id="T_a5db8_row0_col5" class="data row0 col5" >0.355166</td>
#       <td id="T_a5db8_row0_col6" class="data row0 col6" >0.548478</td>
#       <td id="T_a5db8_row0_col7" class="data row0 col7" >0.563672</td>
#     </tr>
#     <tr>
#       <th id="T_a5db8_level0_row1" class="row_heading level0 row1" >CYLINDERS</th>
#       <td id="T_a5db8_row1_col0" class="data row1 col0" >-0.762152</td>
#       <td id="T_a5db8_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_a5db8_row1_col2" class="data row1 col2" >0.956416</td>
#       <td id="T_a5db8_row1_col3" class="data row1 col3" >0.851860</td>
#       <td id="T_a5db8_row1_col4" class="data row1 col4" >0.895801</td>
#       <td id="T_a5db8_row1_col5" class="data row1 col5" >-0.495296</td>
#       <td id="T_a5db8_row1_col6" class="data row1 col6" >-0.327266</td>
#       <td id="T_a5db8_row1_col7" class="data row1 col7" >-0.563010</td>
#     </tr>
#     <tr>
#       <th id="T_a5db8_level0_row2" class="row_heading level0 row2" >DESPLACEMENT</th>
#       <td id="T_a5db8_row2_col0" class="data row2 col0" >-0.794552</td>
#       <td id="T_a5db8_row2_col1" class="data row2 col1" >0.956416</td>
#       <td id="T_a5db8_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_a5db8_row2_col3" class="data row2 col3" >0.886811</td>
#       <td id="T_a5db8_row2_col4" class="data row2 col4" >0.939041</td>
#       <td id="T_a5db8_row2_col5" class="data row2 col5" >-0.511102</td>
#       <td id="T_a5db8_row2_col6" class="data row2 col6" >-0.339440</td>
#       <td id="T_a5db8_row2_col7" class="data row2 col7" >-0.621386</td>
#     </tr>
#     <tr>
#       <th id="T_a5db8_level0_row3" class="row_heading level0 row3" >HORSEPOWER</th>
#       <td id="T_a5db8_row3_col0" class="data row3 col0" >-0.767314</td>
#       <td id="T_a5db8_row3_col1" class="data row3 col1" >0.851860</td>
#       <td id="T_a5db8_row3_col2" class="data row3 col2" >0.886811</td>
#       <td id="T_a5db8_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_a5db8_row3_col4" class="data row3 col4" >0.878883</td>
#       <td id="T_a5db8_row3_col5" class="data row3 col5" >-0.656977</td>
#       <td id="T_a5db8_row3_col6" class="data row3 col6" >-0.369925</td>
#       <td id="T_a5db8_row3_col7" class="data row3 col7" >-0.468959</td>
#     </tr>
#     <tr>
#       <th id="T_a5db8_level0_row4" class="row_heading level0 row4" >WEIGHT</th>
#       <td id="T_a5db8_row4_col0" class="data row4 col0" >-0.828215</td>
#       <td id="T_a5db8_row4_col1" class="data row4 col1" >0.895801</td>
#       <td id="T_a5db8_row4_col2" class="data row4 col2" >0.939041</td>
#       <td id="T_a5db8_row4_col3" class="data row4 col3" >0.878883</td>
#       <td id="T_a5db8_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_a5db8_row4_col5" class="data row4 col5" >-0.397315</td>
#       <td id="T_a5db8_row4_col6" class="data row4 col6" >-0.288992</td>
#       <td id="T_a5db8_row4_col7" class="data row4 col7" >-0.588920</td>
#     </tr>
#     <tr>
#       <th id="T_a5db8_level0_row5" class="row_heading level0 row5" >ACCELERATION</th>
#       <td id="T_a5db8_row5_col0" class="data row5 col0" >0.355166</td>
#       <td id="T_a5db8_row5_col1" class="data row5 col1" >-0.495296</td>
#       <td id="T_a5db8_row5_col2" class="data row5 col2" >-0.511102</td>
#       <td id="T_a5db8_row5_col3" class="data row5 col3" >-0.656977</td>
#       <td id="T_a5db8_row5_col4" class="data row5 col4" >-0.397315</td>
#       <td id="T_a5db8_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_a5db8_row5_col6" class="data row5 col6" >0.233646</td>

# %%
dfMat = df.loc[:, ['MPG', 'DESPLACEMENT', 'HORSEPOWER', 'WEIGHT', 'ACCELERATION', 'MODEL YEAR', 'ORIGIN']]  
correlacion = dfMat.corr(method = 'pearson')  
correlacion.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_48308_row0_col0, #T_48308_row1_col1, #T_48308_row2_col2, #T_48308_row3_col3, #T_48308_row4_col4, #T_48308_row5_col5, #T_48308_row6_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_48308_row0_col1, #T_48308_row0_col2, #T_48308_row0_col3, #T_48308_row1_col6, #T_48308_row2_col4, #T_48308_row2_col5, #T_48308_row3_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T

#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4e406_level0_col0" class="col_heading level0 col0" >MPG</th>
#       <th id="T_4e406_level0_col1" class="col_heading level0 col1" >DESPLACEMENT</th>
#       <th id="T_4e406_level0_col2" class="col_heading level0 col2" >HORSEPOWER</th>
#       <th id="T_4e406_level0_col3" class="col_heading level0 col3" >ACCELERATION</th>
#       <th id="T_4e406_level0_col4" class="col_heading level0 col4" >MODEL YEAR</th>
#       <th id="T_4e406_level0_col5" class="col_heading level0 col5" >ORIGIN</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4e406_level0_row0" class="row_heading level0 row0" >MPG</th>
#       <td id="T_4e406_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_4e406_row0_col1" class="data row0 col1" >-0.794552</td>
#       <td id="T_4e406_row0_col2" class="data row0 col2" >-0.767314</td>
#       <td id="T_4e406_row0_col3" class="data row0 col3" >0.355166</td>
#       <td id="T_4e406_row0_col4" class="data row0 col4" >0.548478</td>
#       <td id="T_4e406_row0_col5" class="data row0 col5" >0.563672</td>
#     </tr>
#     <tr>
#       <th id="T_4e406_level0_row1" class="row_heading level0 row1" >DESPLACEMENT</th>
#       <td id="T_4e406_row1_col0" class="data row1 col0" >-0.794552</td>
#       <td id="T_4e406_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_4e406_row1_col2" class="data row1 col2" >0.886811</td>
#       <td id="T_4e406_row1_col3" class="data row1 col3" >-0.511102</td>
#       <td id="T_4e406_row1_col4" class="data row1 col4" >-0.339440</td>
#       <td id="T_4e406_row1_col5" class="data row1 col5" >-0.621386</td>
#     </tr>
#     <tr>
#       <th id="T_4e406_level0_row2" class="row_heading level0 row2" >HORSEPOWER</th>
#       <td id="T_4e406_row2_col0" class="data row2 col0" >-0.767314</td>
#       <td id="T_4e406_row2_col1" class="data row2 col1" >0.886811</td>
#       <td id="T_4e406_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_4e406_row2_col3" class="data row2 col3" >-0.656977</td>
#       <td id="T_4e406_row2_col4" class="data row2 col4" >-0.369925</td>
#       <td id="T_4e406_row2_col5" class="data row2 col5" >-0.468959</td>
#     </tr>
#     <tr>
#       <th id="T_4e406_level0_row3" class="row_heading level0 row3" >ACCELERATION</th>
#       <td id="T_4e406_row3_col0" class="data row3 col0" >0.355166</td>
#       <td id="T_4e406_row3_col1" class="data row3 col1" >-0.511102</td>
#       <td id="T_4e406_row3_col2" class="data row3 col2" >-0.656977</td>
#       <td id="T_4e406_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_4e406_row3_col4" class="data row3 col4" >0.233646</td>
#       <td id="T_4e406_row3_col5" class="data row3 col5" >0.199191</td>
#     </tr>
#     <tr>
#       <th id="T_4e406_level0_row4" class="row_heading level0 row4" >MODEL YEAR</th>
#       <td id="T_4e406_row4_col0" class="data row4 col0" >0.548478</td>
#       <td id="T_4e406_row4_col1" class="data row4 col1" >-0.339440</td>
#       <td id="T_4e406_row4_col2" class="data row4 col2" >-0.369925</td>
#       <td id="T_4e406_row4_col3" class="data row4 col3" >0.233646</td>
#       <td id="T_4e406_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_4e406_row4_col5" class="data row4 col5" >0.178201</td>
#     </tr>
#     <tr>
#       <th id="T_4e406_level0_row5" class="row_heading level0 row5" >ORIGIN</th>
#       <td id="T_4e406_row5_col0" class="data row5 col0" >0.563672</td>
#       <td id="T_4e406_row5_col1" class="data row5 col1" >-0.621386</td>
#       <td id="T_4e406_row5_col2" class="data row5 col2" >-0.468959</td>
#       <td id="T_4e406_row5_col3" class="data row5 col3" >0.199191</td>
#       <td id="T_4e406_row5_col4" class="data row5 col4" >0.178201</td>
#       <td id="T_4e406_row5_col5" class="data row5 col5" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
dfMat = df.loc[:, ['MPG','HORSEPOWER','ACCELERATION', 'MODEL YEAR', 'ORIGIN']]  
correlacion = dfMat.corr(method = 'pearson')  
correlacion.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_4b663_row0_col0, #T_4b663_row1_col1, #T_4b663_row2_col2, #T_4b663_row3_col3, #T_4b663_row4_col4 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_4b663_row0_col1, #T_4b663_row1_col0, #T_4b663_row1_col2, #T_4b663_row1_col3, #T_4b663_row1_col4 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_4b663_row0_col2 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_4b663_row0_col3 {
#   background-color: #f7b79b;
#   color: #000000;
# }
# #T_4b663_row0_col4 {
#   background-color: #f7ac8e;
#   color: #000000;
# }
# #T_4b663_row2_col0 {
#   background-color: #f5c1a9;
#   color: #000000;
# }
# #T_4b663_row2_col1 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_4b663_row2_col3, #T_4b663_row3_col4 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_4b663_row2_col4 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_4b663_row3_col0 {
#   background-color: #f59c7d;
#   color: #000000;
# }
# #T_4b663_row3_col1 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_4b663_row3_col2 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_4b663_row4_col0 {
#   background-color: #f4987a;
#   color: #000000;
# }
# #T_4b663_row4_col1 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_4b663_row4_col2 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_4b663_row4_col3 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# </style>
# <table id="T_4b663">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4b663_level0_col0" class="col_heading level0 col0" >MPG</th>
#       <th id="T_4b663_level0_col1" class="col_heading level0 col1" >HORSEPOWER</th>
#       <th id="T_4b663_level0_col2" class="col_heading level0 col2" >ACCELERATION</th>
#       <th id="T_4b663_level0_col3" class="col_heading level0 col3" >MODEL YEAR</th>
#       <th id="T_4b663_level0_col4" class="col_heading level0 col4" >ORIGIN</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4b663_level0_row0" class="row_heading level0 row0" >MPG</th>
#       <td id="T_4b663_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_4b663_row0_col1" class="data row0 col1" >-0.767314</td>
#       <td id="T_4b663_row0_col2" class="data row0 col2" >0.355166</td>
#       <td id="T_4b663_row0_col3" class="data row0 col3" >0.548478</td>
#       <td id="T_4b663_row0_col4" class="data row0 col4" >0.563672</td>
#     </tr>
#     <tr>
#       <th id="T_4b663_level0_row1" class="row_heading level0 row1" >HORSEPOWER</th>
#       <td id="T_4b663_row1_col0" class="data row1 col0" >-0.767314</td>
#       <td id="T_4b663_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_4b663_row1_col2" class="data row1 col2" >-0.656977</td>
#       <td id="T_4b663_row1_col3" class="data row1 col3" >-0.369925</td>
#       <td id="T_4b663_row1_col4" class="data row1 col4" >-0.468959</td>
#     </tr>
#     <tr>
#       <th id="T_4b663_level0_row2" class="row_heading level0 row2" >ACCELERATION</th>
#       <td id="T_4b663_row2_col0" class="data row2 col0" >0.355166</td>
#       <td id="T_4b663_row2_col1" class="data row2 col1" >-0.656977</td>
#       <td id="T_4b663_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_4b663_row2_col3" class="data row2 col3" >0.233646</td>
#       <td id="T_4b663_row2_col4" class="data row2 col4" >0.199191</td>
#     </tr>
#     <tr>
#       <th id="T_4b663_level0_row3" class="row_heading level0 row3" >MODEL YEAR</th>
#       <td id="T_4b663_row3_col0" class="data row3 col0" >0.548478</td>
#       <td id="T_4b663_row3_col1" class="data row3 col1" >-0.369925</td>
#       <td id="T_4b663_row3_col2" class="data row3 col2" >0.233646</td>
#       <td id="T_4b663_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_4b663_row3_col4" class="data row3 col4" >0.178201</td>
#     </tr>
#     <tr>
#       <th id="T_4b663_level0_row4" class="row_heading level0 row4" >ORIGIN</th>
#       <td id="T_4b663_row4_col0" class="data row4 col0" >0.563672</td>
#       <td id="T_4b663_row4_col1" class="data row4 col1" >-0.468959</td>
#       <td id="T_4b663_row4_col2" class="data row4 col2" >0.199191</td>
#       <td id="T_4b663_row4_col3" class="data row4 col3" >0.178201</td>
#       <td id="T_4b663_row4_col4" class="data row4 col4" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
dfMat.head(6)
# Out:
#     MPG  HORSEPOWER  ACCELERATION  MODEL YEAR  ORIGIN
# 0  18.0       130.0          12.0          70       1
# 1  15.0       165.0          11.5          70       1
# 2  18.0       150.0          11.0          70       1
# 3  16.0       150.0          12.0          70       1
# 4  17.0       140.0          10.5          70       1
# 5  15.0       198.0          10.0          70       1

# %%
viz = dfMat[['MPG','HORSEPOWER','ACCELERATION','MODEL YEAR','ORIGIN']] 
viz.hist()
plt.show()

# %%
msk = np.random.rand(len(dfMat)) < 0.8
train = dfMat[msk]
test = dfMat[~msk]

# %%
train.head(5)
# Out:
#     MPG  HORSEPOWER  ACCELERATION  MODEL YEAR  ORIGIN
# 0  18.0       130.0          12.0          70       1
# 1  15.0       165.0          11.5          70       1
# 2  18.0       150.0          11.0          70       1
# 3  16.0       150.0          12.0          70       1
# 5  15.0       198.0          10.0          70       1

# %%
test.head(5)
# Out:
#      MPG  HORSEPOWER  ACCELERATION  MODEL YEAR  ORIGIN
# 4   17.0       140.0          10.5          70       1
# 20  24.0        95.0          15.0          70       3
# 24  27.0        88.0          14.5          70       3
# 35  27.0        88.0          14.5          71       3
# 45  14.0       165.0          12.0          71       1

# %%
regr = linear_model.LinearRegression()
x = np.asanyarray(train[['HORSEPOWER','ACCELERATION','MODEL YEAR','ORIGIN']]) #MULTIPLE
#x = np.asanyarray(train[['HORSEPOWER']]) #SIMPLE
y = np.asanyarray(train[['MPG']])
regr.fit(x,y)
print('Coeficientes:', regr.coef_)
# Out:
# Coeficientes: [[-0.15269809 -0.57570952  0.5766945   1.94288087]]

# %%
y_hat = regr.predict(test[['HORSEPOWER','ACCELERATION','MODEL YEAR','ORIGIN']])
x = np.asanyarray(test[['HORSEPOWER','ACCELERATION','MODEL YEAR','ORIGIN']]) #MULTIPLE
#x = np.asanyarray(test[['HORSEPOWER']]) #SIMPLE
y = np.asanyarray(test[['MPG']])
print('Error Residual Medio (RSE): %.2f' % np.mean((y_hat - y)**2))
print('Confianza: %.2f' % regr.score(x,y))
# Out:
# Error Residual Medio (RSE): 13.66
# Confianza: 0.76
# C:\Users\USER\anaconda3\envs\C2024\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(

# %%
df = pd.DataFrame({'Valor Actual': y.flatten(), 'Prediccion': y_hat.flatten()})
df.head(10)
# Out:
#    Valor Actual  Prediccion
# 0          17.0   16.360499
# 1          24.0   24.526982
# 2          27.0   25.883723
# 3          27.0   26.460418
# 4          14.0   12.256177
# 5          18.0   22.574656
# 6          14.0   14.089539
# 7          13.0   13.496288
# 8          12.0   12.732798
# 9          19.0   26.238539

# %%
df1 = df.head(15)
df1.plot(kind='bar',figsize=(16,10))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()
